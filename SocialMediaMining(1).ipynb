# %% [markdown]
# # **Les différentes étapes à accomplir :**

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# # 1) Importer l'ensemble de données **Ethos_Dataset_for_hate_speech_detection.csv** dans un DataFrame data via **la connection au drive** et en utilisant la fonction **read_csv**.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2) **Détecter la langue** de chaque tweet dans l'ensemble de données, et le **traduire en anglais** en utilisant le package **googletrans avec la version 3.1.0a0**.

# %%
# !pip install googletrans==3.1.0a0

# %% [markdown]
# # 3) Préparer les données textuelles (les tweets) en accomplissant **une étape de prétraitement** qui comprend : la **conversion des commentaires en minuscules**, la suppression **des symboles**, **des espaces successives**, **des mots vides** (stopwords), des **liens hypertextes**, **des @nom** et la **lemmatization** des mots (convertir chaque mot en sa racine).

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %% [markdown]
# # 4) **Analyser le sentiment** de chaque texte en déterminant sa **subjectivité** et étiqueter les tweets subjectifs comme étant **positif, négatif ou neutre** en se basant sur leurs polarités et en utilisant le package **TextBlob**.
# ## - TextBlob: une bibliothèque populaire en python dédiée au traitement du langage naturel (NLP-Natural Language Processing). Il offre une interface simple pour accéder à diverses tâches de NLP telles que, l'analyse des sentiments et la traduction des textes.

# %%
from textblob import TextBlob

# %% [markdown]
# # 5) Utiliser le package **Empath** pour **extraire les émotions** transmises dans chaque texte.
# ## - Empath : une bibliothèque Python conçue pour l'analyse de texte et l'analyse des sentiments.
# ## Elle permet d'analyser des données textuelles et elle peut permettre, en particulier, d'identifier différentes catégories d'émotions ou de sentiments exprimés dans le texte (200 catégories : love, sadness, surprise, anger, etc...)

# %%
# !pip install empath

# %% [markdown]
# # 6) Sauvegarder les tweets préparés au format csv.

# %% [markdown]
# # **Hate speech detection**

# %% [markdown]
# ## 7) Importer l'ensemble de données **Ethos_Dataset_for_hate_speech_detection.csv** dans un DataFrame data en utilisant la fonction read_csv.

# %% [markdown]
# # 8) Représenter chaque commentaire par une **représentation vectorielle** en utilisant le modèle **Word2Vec**.

# %%
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
import numpy as np

# %% [markdown]
# # 9) **Représenter** chaque commentaire par une représentation vectorielle en utilisant le modèle **Doc2Vec**.

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.tokenize import word_tokenize

# %% [markdown]
# # 10) Entraîner le modèle **autoencoder** par les représentations des tweets obtenues par le modèle **Word2Vec** pour obtenir des représentations compactes des données.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# # 11) Séparer les données d'entraînement, des données de test. Entraîner et évaluer **le modèle SVM** en utilisant les représentations produites par l'autoencodeur, puis celles produites par le modèle doc2vec..

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# # 12) Entraîner et évaluer **le modèle MLP** (Multilayer Perceptron) en utilisant les représentations produites par l'autoencodeur, puis celles produites par le modèle doc2vec.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
